# %%
pip install ipython-sql
# Out:
# Collecting ipython-sqlNote: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask-appbuilder 4.3.0 requires SQLAlchemy<1.5, but you have sqlalchemy 2.0.13 which is incompatible.
# apache-airflow 2.6.0 requires sqlalchemy<2.0,>=1.4, but you have sqlalchemy 2.0.13 which is incompatible.
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\marce\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
#   Downloading ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Collecting prettytable
#   Downloading prettytable-3.7.0-py3-none-any.whl (27 kB)
# Collecting sqlalchemy>=2.0
#   Downloading SQLAlchemy-2.0.13-cp310-cp310-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: sqlparse in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (0.4.4)
# Requirement already satisfied: ipython in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (8.7.0)
# Requirement already satisfied: six in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (1.1.2)
# Requirement already satisfied: matplotlib-inline in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: backcall in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (3.0.36)
# Requirement already satisfied: colorama in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.4.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (2.13.0)
# Requirement already satisfied: decorator in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.18.2)
# Requirement already satisfied: pickleshare in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: traitlets>=5 in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: stack-data in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.6.2)
# Requirement already satisfied: wcwidth in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\marce\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (1.2.0)
# Installing collected packages: sqlalchemy, prettytable, ipython-sql
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.25
#     Uninstalling SQLAlchemy-1.4.25:
#       Successfully uninstalled SQLAlchemy-1.4.25
# Successfully installed ipython-sql-0.5.0 prettytable-3.7.0 sqlalchemy-2.0.13

# %%
import boto3
import json
import configparser
from botocore.exceptions import ClientError
import time
import pandas as pd
import psycopg2

# %%
config = configparser.ConfigParser()
config.read_file(open('dwh.cfg'))
KEY                    = config.get('AWS','KEY')
SECRET                 = config.get('AWS','SECRET')

DWH_CLUSTER_TYPE       = config.get("DWH","DWH_CLUSTER_TYPE")
DWH_NUM_NODES          = config.get("DWH","DWH_NUM_NODES")
DWH_NODE_TYPE          = config.get("DWH","DWH_NODE_TYPE")

DWH_CLUSTER_IDENTIFIER = config.get("DWH","DWH_CLUSTER_IDENTIFIER")
DWH_DB                 = config.get("DWH","DWH_DB")
DWH_DB_USER            = config.get("DWH","DWH_DB_USER")
DWH_DB_PASSWORD        = config.get("DWH","DWH_DB_PASSWORD")
DWH_PORT               = config.get("DWH","DWH_PORT")

DWH_IAM_ROLE_NAME      = config.get("DWH", "DWH_IAM_ROLE_NAME")

pd.DataFrame({"Param":
                  ["DWH_CLUSTER_TYPE", "DWH_NUM_NODES", "DWH_NODE_TYPE", "DWH_CLUSTER_IDENTIFIER", "DWH_DB", "DWH_DB_USER", "DWH_DB_PASSWORD", "DWH_PORT", "DWH_IAM_ROLE_NAME"],
              "Value":
                  [DWH_CLUSTER_TYPE, DWH_NUM_NODES, DWH_NODE_TYPE, DWH_CLUSTER_IDENTIFIER, DWH_DB, DWH_DB_USER, DWH_DB_PASSWORD, DWH_PORT, DWH_IAM_ROLE_NAME]
             })
# Out:
#                     Param                     Value
# 0        DWH_CLUSTER_TYPE                multi-node
# 1           DWH_NUM_NODES                         8
# 2           DWH_NODE_TYPE                 dc2.large
# 3  DWH_CLUSTER_IDENTIFIER           airflow-cluster
# 4                  DWH_DB                       dev
# 5             DWH_DB_USER                   awsuser
# 6         DWH_DB_PASSWORD               awsuser123X
# 7                DWH_PORT                      5439
# 8       DWH_IAM_ROLE_NAME  my-redshift-service-role

# %%
# Create clients for EC2, S3, IAM, and Redshift
ec2 = boto3.resource('ec2', 
                     region_name='us-east-1',
                     aws_access_key_id=KEY,
                     aws_secret_access_key=SECRET)

iam = boto3.client('iam',
                   region_name='us-east-1',
                   aws_access_key_id=KEY,
                   aws_secret_access_key=SECRET)

redshift = boto3.client('redshift',
                        region_name="us-east-1",
                        aws_access_key_id=KEY,
                        aws_secret_access_key=SECRET)


s3 = boto3.resource('s3',
                       region_name="us-east-1",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                   )

# %%
### CREATING IAM ROLE

def create_IAM_Role(iam, DWH_IAM_ROLE_NAME):
    try:
        print("Creating a new IAM Role")
        dwhRole = iam.create_role(
            Path="/",
            RoleName=DWH_IAM_ROLE_NAME,
            Description="Allows Redshift clusters to call AWS services on your behalf.",
            AssumeRolePolicyDocument=json.dumps(
                {
                    "Statement": [
                        {
                            "Action": "sts:AssumeRole",
                            "Effect": "Allow",
                            "Principal": {"Service": "redshift.amazonaws.com"},
                        }
                    ],
                    "Version": "2012-10-17",
                }
            ),
        )
    except Exception as e:
        print("       " + str(e))

    print("Attaching Policy")

    iam.attach_role_policy(
        RoleName=DWH_IAM_ROLE_NAME,
        PolicyArn="arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess",
    )["ResponseMetadata"]["HTTPStatusCode"]

    print("Getting the IAM role ARN")
    roleArn = iam.get_role(RoleName=DWH_IAM_ROLE_NAME)["Role"]["Arn"]
    print("       IAM role ARN: " + roleArn)
    return roleArn

create_IAM_Role(iam, DWH_IAM_ROLE_NAME)
print("Role Created")

roleArn = iam.get_role(RoleName=DWH_IAM_ROLE_NAME)["Role"]["Arn"]
print("Role ARN:  " + roleArn)

# %%
sampleDbBucket =  s3.Bucket("awssampledbuswest2")
for obj in sampleDbBucket.objects.filter(Prefix="ssbgz"):
    print(obj)
# for obj in sampleDbBucket.objects.all():
#     print(obj)

# %%
# Create the Redshift cluster
try:
    response = redshift.create_cluster(        
        #HW
        ClusterType=DWH_CLUSTER_TYPE,
        NodeType=DWH_NODE_TYPE,
        NumberOfNodes=int(DWH_NUM_NODES),

        #Identifiers & Credentials
        DBName=DWH_DB,
        ClusterIdentifier=DWH_CLUSTER_IDENTIFIER,
        MasterUsername=DWH_DB_USER,
        MasterUserPassword=DWH_DB_PASSWORD,
        
        #Roles (for s3 access)
        IamRoles=[roleArn],
        
        #Adding default and redshift security group
        VpcSecurityGroupIds=['sg-0f506cb55b40be268', 'sg-0b71fb5617de2365b']
    )
except Exception as e:
    print(e)

# %%
## Creating the cluster might take from 3-15m

def prettyRedshiftProps(props):
    pd.set_option('display.max_colwidth', -1)
    keysToShow = ["ClusterIdentifier", "NodeType", "ClusterStatus", "MasterUsername", "DBName", "Endpoint", "NumberOfNodes", 'VpcId']
    x = [(k, v) for k,v in props.items() if k in keysToShow]
    return pd.DataFrame(data=x, columns=["Key", "Value"])

myClusterProps = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
prettyRedshiftProps(myClusterProps)
# Out:
# C:\Users\marce\AppData\Local\Temp\ipykernel_23532\1078158154.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                  Key  \
# 0  ClusterIdentifier
# 1  NodeType
# 2  ClusterStatus
# 3  MasterUsername
# 4  DBName
# 5  Endpoint
# 6  VpcId
# 7  NumberOfNodes
#
#                                                                                         Value
# 0  airflow-cluster
# 1  ra3.4xlarge
# 2  available
# 3  awsuser
# 4  dev
# 5  {'Address': 'airflow-cluster.cqrkiu1bhedl.us-east-1.redshift.amazonaws.com', 'Port': 5439}
# 6  vpc-0b312c20999a13d89
# 7  4

# %%
DWH_ENDPOINT = myClusterProps['Endpoint']['Address']
DWH_ROLE_ARN = myClusterProps['IamRoles'][0]['IamRoleArn']
print("DWH_ENDPOINT :: ", DWH_ENDPOINT)
print("DWH_ROLE_ARN :: ", DWH_ROLE_ARN)
# Out:
# DWH_ENDPOINT ::  airflow-cluster.cqrkiu1bhedl.us-east-1.redshift.amazonaws.com
# DWH_ROLE_ARN ::  arn:aws:iam::137423019814:role/my-redshift-service-role

# %%
# Open an incoming  TCP port to access the cluster endpoint
try:
    vpc = ec2.Vpc(id=myClusterProps['VpcId'])
    defaultSg = list(vpc.security_groups.all())[0]
    print(defaultSg)
    defaultSg.authorize_ingress(
        GroupName=defaultSg.group_name,
        CidrIp='0.0.0.0/0',
        IpProtocol='TCP',
        FromPort=int(DWH_PORT),
        ToPort=int(DWH_PORT)
    )
except Exception as e:
    print(e)
# Out:
# ec2.SecurityGroup(id='sg-0f506cb55b40be268')
# An error occurred (InvalidPermission.Duplicate) when calling the AuthorizeSecurityGroupIngress operation: the specified rule "peer: 0.0.0.0/0, TCP, from port: 5439, to port: 5439, ALLOW" already exists

# %%
# %reload_ext sql

# %%
conn_string="postgresql://{}:{}@{}:{}/{}".format(DWH_DB_USER, DWH_DB_PASSWORD, DWH_ENDPOINT, DWH_PORT,DWH_DB)
print(conn_string)
# %sql $conn_string
# Out:
# postgresql://awsuser:awsuser123X@airflow-cluster.cqrkiu1bhedl.us-east-1.redshift.amazonaws.com:5439/dev
# Traceback (most recent call last):
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py", line 1963, in _exec_single_context
#     self.dialect.do_execute(
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\default.py", line 920, in do_execute
#     cursor.execute(statement, parameters)
# psycopg2.errors.UndefinedObject: unrecognized configuration parameter "standard_conforming_strings"
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sql\connection.py", line 70, in set
#     cls.current = existing or Connection(descriptor, connect_args, creator)
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sql\connection.py", line 55, in __init__
#     self.internal_connection = engine.connect()
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py", line 3264, in connect
#     return self._connection_cls(self)
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py", line 145, in __init__
#     self._dbapi_connection = engine.raw_connection()
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py", line 3288, in raw_connection
#     return self.pool.connect()
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\pool\base.py", line 452, in connect
#     return _ConnectionFairy._checkout(self)
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\pool\base.py", line 1268, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\pool\base.py", line 716, in checkout
#     rec = pool._do_get()
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\pool\impl.py", line 168, in _do_get
#     with util.safe_reraise():
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\util\langhelpers.py", line 147, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\pool\impl.py", line 166, in _do_get
#     return self._create_connection()
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\pool\base.py", line 393, in _create_connection
#     return _ConnectionRecord(self)
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\pool\base.py", line 678, in __init__
#     self.__connect()
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\pool\base.py", line 916, in __connect
#     )._exec_w_sync_on_first_run(self.dbapi_connection, self)
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\event\attr.py", line 473, in _exec_w_sync_on_first_run
#     self(*args, **kw)
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\event\attr.py", line 487, in __call__
#     fn(*args, **kw)
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\util\langhelpers.py", line 1915, in go
#     return once_fn(*arg, **kw)
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\create.py", line 733, in first_connect
#     dialect.initialize(c)
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py", line 656, in initialize
#     super().initialize(connection)
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\dialects\postgresql\base.py", line 3017, in initialize
#     self._set_backslash_escapes(connection)
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\dialects\postgresql\base.py", line 4693, in _set_backslash_escapes
#     std_string = connection.exec_driver_sql(
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py", line 1771, in exec_driver_sql
#     ret = self._execute_context(
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py", line 1841, in _execute_context
#     return self._exec_single_context(
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py", line 1982, in _exec_single_context
#     self._handle_dbapi_exception(
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py", line 2339, in _handle_dbapi_exception
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py", line 1963, in _exec_single_context
#     self.dialect.do_execute(
#   File "C:\Users\marce\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\default.py", line 920, in do_execute
#     cursor.execute(statement, parameters)
# sqlalchemy.exc.ProgrammingError: (psycopg2.errors.UndefinedObject) unrecognized configuration parameter "standard_conforming_strings"
#
# [SQL: show standard_conforming_strings]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
print("Execution finished, please add your redshift database and IAM role info to dwh.cfg before proceeding to create tables")
